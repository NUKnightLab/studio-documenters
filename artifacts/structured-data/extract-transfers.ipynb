# %% [markdown]
# # Transfer extraction script
#
# Extracts transfers of funds from Chicago Board of Education agendas and exports them as CSV files. Handles some edge cases, but OCR issues can cause some transfers to not be parsed properly.

# %%
import json
from collections import Counter

docs_metadata = json.load(open('../data/DocumentCloud/documents.json'))

STOP_WORDS = ['Detroit', 'Cleveland', 'Akron', 'Ohio', 'Allegheny', 'Cuyahoga', 'Summit County', 'Wayne County', 'Michigan' ]
def chicago_filter(doc_json):
    for word in STOP_WORDS:
        if word.lower() in doc_json['source'].lower():
            return False
    return True

# Filter non-Chicago documents
filtered_docs = filter(chicago_filter, docs_metadata)
chicago_docs = [x for x in filtered_docs]

# %%
"""Return document information for a given source.

source: search keyword for source name, case insensitive. Empty string searches all sources.
title_keyword: search keyword for document title, case insensitive. Default: ""
only_title: If set to True, only returns title of matching documents, not the entire json as dict. Default: False.
"""
def get_docs_for_source(source, title_keyword="", only_title=False):
    filter_func = lambda x:  source.lower() in x['source'].lower()
    if title_keyword:
        filter_func = lambda x:  source.lower() in x['source'].lower() and title_keyword in x['title'].lower()
    source_filter = filter(filter_func, chicago_docs)
    if not only_title:
        source_docs = [x for x in source_filter]
    else:
        source_docs = [x['title'] for x in source_filter]
    print("Documents found in {}: {}".format(source, len(source_docs)))
    return source_docs

# %%
import re

TEXT_DATABASE_PATH = "../data/DocumentCloud/text/"
ACTION_ID = "ACTION ID"
UNFORMATTED_KEY = "UNFORMATTED"


"""Process a single set of transfers. Returns transfers as a list of dictionaries.

action_id: The action id associated with the given set of transfers.
action_text: The text containing the transfers.
"""
def process_transfer_action(action_id, action_text):
    
    # Split text into individual transfers by numbered heading (i.e. "2.", "45.")
    transfers = re.split('^\s*([0-9]+)\.', action_text, flags=re.MULTILINE)
    
    # Create list of pairs (transfer number, transfer text)
    transfer_list = []
    for i in range(1, len(transfers), 2):
        transfer_list.append((transfers[i], transfers[i+1]))
    
    
    transfer_rows = []
    for t in transfer_list:
        transfer_info = {"Number": t[0], "Action": action_id}
        
        # Split transfer into sections.
        sections = t[1].split("\n\n")
        
        # Remove page numbers and whitespace.
        cleaned_sections = [x for x in sections if x.strip() and x.strip() != action_id and not x.isnumeric()]

        
        for i, x in enumerate(cleaned_sections):
            if i == 0:
                # First section is typically the name with "Rationale:" appended to the end
                name = x.replace("\nRationale:", "")
                transfer_info["Name"] = name
            elif i == 1:
                # Second section is typically the rationale for the transfer.
                transfer_info["Rationale"] = x
            else:
                # Amount can be in different sections. If "Amount:" is present, extract dollar amount
                split_x = x.split("Amount:")
                if len(split_x) > 1:
                    transfer_info["Amount"] = split_x[1].strip()
                    x = split_x[0]
                
                # Each line in the transfer details starts with an id number - split by those
                split_section = re.split('^([0-9]+)\s', x, flags=re.MULTILINE)
                
                # First line indicates whether section contains "From" or "To" information
                section_type = ""
                if "Transfer From:" in split_section[0]:
                    section_type = "From"
                elif "Transfer To:" in split_section[0]:
                    section_type = "To"

                if section_type:
                    for j in range(1, len(split_section), 2):
                        # Example headers: "From Line 1", "From Line 2" ... "To Line 1", "To Line 2" ...
                        header = "{} Line {}".format(section_type, int((j+1)/2))
                        transfer_info[header] = (split_section[j] + " " + split_section[j+1]).strip()
                elif x.strip():
                    # Remaining text stored in last column
                    if UNFORMATTED_KEY in transfer_info:
                        transfer_info[UNFORMATTED_KEY] += x
                    else:
                        transfer_info[UNFORMATTED_KEY] = x
                        
        transfer_rows.append(transfer_info)
    return transfer_rows
    
"""Extract transfers from a document.

doc_id: Document id.
"""
def extract_transfers(doc_id):
    # Get document text.
    fname = TEXT_DATABASE_PATH + doc_id + ".txt"
    with open(fname, "r") as f:
        doc_text = f.read()
    
    # Split document into actions. Board of Education actions have the format ##-####
    actions = re.split('(^\d\d-\d\d\d\d-[a-zA-Z][a-zA-Z]\d$)', doc_text, flags=re.MULTILINE)
    action_list = []
    for i in range(1, len(actions), 2):
        action_list.append((actions[i], actions[i+1]))
    
    # Get actions that contain transfers of funds
    transfer_actions = set()
    for a in action_list:
        if "TRANSFER OF FUNDS" in a[1]:
            transfer_actions.add(a[0])
    
    # Process actions with transfers of funds, and add them to a single list of transfers
    transfers = []
    for action_id in transfer_actions:
        action_text = ""
        for a in action_list:
            if a[0] == action_id:
                action_text += a[1]
        transfers += process_transfer_action(action_id, action_text)
    return transfers

# %%
import csv
import os

FOLDER_NAME = "transfers"

"""Extracts transfers from agendas and exports them to csv files.

school_agendas: List of BOE agendas as dicts
"""
def export_transfers(school_agendas):
    for agenda in school_agendas:
        agenda_name = agenda["title"]
        print("Document Name: {}".format(agenda_name))
        print("Document URL: {}".format(agenda["canonical_url"]))
        transfers = extract_transfers(agenda["id"])
        transfer_count = len(transfers)
        print("Number of transfers extracted: {}".format(transfer_count))
        key_counts = sum_key_counts(transfers)
        print("Keys: {} \n".format(str(key_counts)))
        if transfer_count > 0:
            export_csv(agenda_name, key_counts, transfers)

"""Count occurances of keys in processed transfers.

transfers: Processed transfers as list of dicts.
"""
def sum_key_counts(transfers):
    key_counts = {}
    for c in transfers:
        for k in c.keys():
            if k in key_counts:
                key_counts[k] += 1
            else:
                key_counts[k] = 1
    return key_counts

"""Export transfers to csv file in subdirectory.

transfers: Processed transfers as list of dicts.
"""
def export_csv(name, key_counts, transfers):
    keys = key_counts.keys()
    if not os.path.exists(FOLDER_NAME):
        os.makedirs(FOLDER_NAME)
    date = re.search(r'\d{4}-\d{2}-\d{2}', name)
    with open("{}/BOE Agenda Transfer of Funds - {} .csv".format(FOLDER_NAME, date.group()), "w") as output_file:
        dict_writer = csv.DictWriter(output_file, keys)
        dict_writer.writeheader()
        dict_writer.writerows(transfers)

# %%
school_agendas = get_docs_for_source("Chicago Public Schools", title_keyword="agenda")
export_transfers(school_agendas)
# Out:
# Documents found in Chicago Public Schools: 30
# Document Name: Board of Education 2019-12-11 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6572197-Board-of-Education-2019-12-11-Agenda-For-The.html
# Number of transfers extracted: 1026
# Keys: {'Number': 1026, 'Action': 1026, 'Name': 1026, 'Rationale': 1026, 'From Line 1': 1026, 'From Line 2': 1025, 'From Line 3': 1025, 'From Line 4': 1025, 'From Line 5': 1003, 'To Line 1': 1026, 'To Line 2': 1026, 'To Line 3': 1026, 'To Line 4': 1026, 'To Line 5': 1010, 'Amount': 1026, 'UNFORMATTED': 45}
#
# Document Name: Board of Education 2019-11-20 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6553016-Board-of-Education-2019-11-20-Agenda-For-The.html
# Number of transfers extracted: 4171
# Keys: {'Number': 4171, 'Action': 4171, 'Name': 4171, 'Rationale': 4170, 'From Line 1': 4169, 'From Line 2': 4169, 'From Line 3': 4169, 'From Line 4': 4169, 'From Line 5': 4073, 'To Line 1': 4168, 'To Line 2': 4168, 'To Line 3': 4168, 'To Line 4': 4167, 'To Line 5': 4056, 'Amount': 4170, 'UNFORMATTED': 220}
#
# Document Name: Board of Education 2019-03-27 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6523788-Board-of-Education-2019-03-27-Agenda-For-The.html
# Number of transfers extracted: 981
# Keys: {'Number': 981, 'Action': 981, 'Name': 981, 'Rationale': 981, 'From Line 1': 979, 'From Line 2': 979, 'From Line 3': 979, 'From Line 4': 979, 'From Line 5': 960, 'To Line 1': 980, 'To Line 2': 980, 'To Line 3': 980, 'To Line 4': 980, 'To Line 5': 971, 'Amount': 981, 'UNFORMATTED': 176}
#
# Document Name: Board of Education 2019-09-25 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512084-Board-of-Education-2019-09-25-Agenda-For-The.html
# Number of transfers extracted: 1560
# Keys: {'Number': 1560, 'Action': 1560, 'Name': 1560, 'Rationale': 1560, 'From Line 1': 1558, 'From Line 2': 1558, 'From Line 3': 1558, 'From Line 4': 1558, 'From Line 5': 1462, 'To Line 1': 1558, 'To Line 2': 1558, 'To Line 3': 1558, 'To Line 4': 1558, 'To Line 5': 1557, 'Amount': 1558, 'UNFORMATTED': 101, 'From Line 6': 1}
#
# Document Name: Special board meeting 2019-09-18 - Agenda For The Special Board Meeting Of The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512077-Special-board-meeting-2019-09-18-Agenda-For-The.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2019-07-24 - Agenda For The Board Of Education Meeting
# Document URL: https://www.documentcloud.org/documents/6512059-Board-of-Education-2019-07-24-Agenda-For-The.html
# Number of transfers extracted: 1168
# Keys: {'Number': 1168, 'Action': 1168, 'Name': 1168, 'Rationale': 1168, 'From Line 1': 1168, 'From Line 2': 1168, 'From Line 3': 1168, 'From Line 4': 1168, 'From Line 5': 1123, 'To Line 1': 1168, 'To Line 2': 1168, 'To Line 3': 1168, 'To Line 4': 1168, 'To Line 5': 1151, 'Amount': 1168, 'UNFORMATTED': 73}
#
# Document Name: Board of Education 2019-08-28 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512056-Board-of-Education-2019-08-28-Agenda-For-The.html
# Number of transfers extracted: 1325
# Keys: {'Number': 1325, 'Action': 1325, 'Name': 1325, 'Rationale': 1325, 'From Line 1': 425, 'From Line 2': 425, 'From Line 3': 425, 'From Line 4': 425, 'From Line 5': 411, 'To Line 1': 490, 'To Line 2': 490, 'To Line 3': 490, 'To Line 4': 490, 'To Line 5': 482, 'Amount': 773, 'UNFORMATTED': 27}
#
# Document Name: Finance and Audit Committee 2019-07-24 - Agenda For The Chicago Board Of Education Finance And Audit Committee Meeting
# Document URL: https://www.documentcloud.org/documents/6512054-Finance-and-Audit-Committee-2019-07-24-Agenda.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2019-04-24 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512053-Board-of-Education-2019-04-24-Agenda-For-The.html
# Number of transfers extracted: 1106
# Keys: {'Number': 1106, 'Action': 1106, 'Name': 1106, 'Rationale': 1106, 'From Line 1': 1106, 'From Line 2': 1106, 'From Line 3': 1106, 'From Line 4': 1106, 'From Line 5': 1078, 'To Line 1': 1106, 'To Line 2': 1106, 'To Line 3': 1106, 'To Line 4': 1106, 'To Line 5': 1094, 'Amount': 1106, 'UNFORMATTED': 187}
#
# Document Name: Board of Education 2019-06-26 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512052-Board-of-Education-2019-06-26-Agenda-For-The.html
# Number of transfers extracted: 1425
# Keys: {'Number': 1425, 'Action': 1425, 'Name': 1425, 'Rationale': 1425, 'From Line 1': 1425, 'From Line 2': 1425, 'From Line 3': 1425, 'From Line 4': 1425, 'From Line 5': 1394, 'To Line 1': 1425, 'To Line 2': 1425, 'To Line 3': 1425, 'To Line 4': 1425, 'To Line 5': 1377, 'Amount': 1425, 'UNFORMATTED': 88}
#
# Document Name: Board of Education 2019-05-22 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512051-Board-of-Education-2019-05-22-Agenda-For-The.html
# Number of transfers extracted: 1027
# Keys: {'Number': 1027, 'Action': 1027, 'Name': 1027, 'Rationale': 1027, 'From Line 1': 1027, 'From Line 2': 1027, 'From Line 3': 1027, 'From Line 4': 1027, 'From Line 5': 1001, 'To Line 1': 1027, 'To Line 2': 1027, 'To Line 3': 1027, 'To Line 4': 1027, 'To Line 5': 1025, 'Amount': 1027, 'UNFORMATTED': 188}
#
# Document Name: Finance and Audit Committee 2019-04-24 - Agenda For The Chicago Board Of Education Finance And Audit Committee Meeting
# Document URL: https://www.documentcloud.org/documents/6512050-Finance-and-Audit-Committee-2019-04-24-Agenda.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2019-02-27 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512049-Board-of-Education-2019-02-27-Agenda-For-The.html
# Number of transfers extracted: 569
# Keys: {'Number': 569, 'Action': 569, 'Name': 569, 'Rationale': 569, 'From Line 1': 569, 'From Line 2': 569, 'From Line 3': 569, 'From Line 4': 569, 'From Line 5': 555, 'To Line 1': 569, 'To Line 2': 569, 'To Line 3': 569, 'To Line 4': 569, 'To Line 5': 560, 'Amount': 569, 'UNFORMATTED': 26}
#
# Document Name: Finance and Audit Committee 2018-10-24 - Agenda For The Chicago Board Of Education Finance And Audit Committee Meeting
# Document URL: https://www.documentcloud.org/documents/6512047-Finance-and-Audit-Committee-2018-10-24-Agenda.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2018-10-24 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512046-Board-of-Education-2018-10-24-Agenda-For-The.html
# Number of transfers extracted: 1283
# Keys: {'Number': 1283, 'Action': 1283, 'Name': 1283, 'Rationale': 1283, 'From Line 1': 1283, 'From Line 2': 1283, 'From Line 3': 1283, 'From Line 4': 1283, 'From Line 5': 1216, 'To Line 1': 1283, 'To Line 2': 1283, 'To Line 3': 1283, 'To Line 4': 1283, 'To Line 5': 1260, 'Amount': 1283, 'UNFORMATTED': 98}
#
# Document Name: Board of Education 2019-01-23 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512045-Board-of-Education-2019-01-23-Agenda-For-The.html
# Number of transfers extracted: 992
# Keys: {'Number': 992, 'Action': 992, 'Name': 992, 'Rationale': 992, 'From Line 1': 992, 'From Line 2': 992, 'From Line 3': 992, 'From Line 4': 992, 'From Line 5': 964, 'To Line 1': 992, 'To Line 2': 992, 'To Line 3': 992, 'To Line 4': 992, 'To Line 5': 986, 'Amount': 992, 'UNFORMATTED': 148}
#
# Document Name: Finance and Audit Committee 2019-01-23 - Agenda For The Chicago Board Of Education Finance And Audit Committee Meeting
# Document URL: https://www.documentcloud.org/documents/6512044-Finance-and-Audit-Committee-2019-01-23-Agenda.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2018-12-05 - Agenda For The Rescheduled Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512043-Board-of-Education-2018-12-05-Agenda-For-The.html
# Number of transfers extracted: 3660
# Keys: {'Number': 3660, 'Action': 3660, 'Name': 3660, 'Rationale': 3660, 'From Line 1': 3659, 'From Line 2': 3659, 'From Line 3': 3659, 'From Line 4': 3659, 'From Line 5': 3603, 'To Line 1': 3659, 'To Line 2': 3659, 'To Line 3': 3658, 'To Line 4': 3658, 'To Line 5': 3611, 'Amount': 3660, 'UNFORMATTED': 332}
#
# Document Name: Finance and Audit Committee 2018-04-25 - Agenda For The Chicago Board Of Education Finance And Audit Committee Meeting
# Document URL: https://www.documentcloud.org/documents/6512042-Finance-and-Audit-Committee-2018-04-25-Agenda.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2018-09-26 - Agenda Fo
# Document URL: https://www.documentcloud.org/documents/6512041-Board-of-Education-2018-09-26-Agenda-Fo.html
# Number of transfers extracted: 1563
# Keys: {'Number': 1563, 'Action': 1563, 'Name': 1563, 'Rationale': 1563, 'From Line 1': 1549, 'From Line 2': 1549, 'From Line 3': 1549, 'From Line 4': 1549, 'From Line 5': 1516, 'To Line 1': 1549, 'To Line 2': 1549, 'To Line 3': 1549, 'To Line 4': 1549, 'To Line 5': 1511, 'Amount': 1563, 'UNFORMATTED': 76}
#
# Document Name: Finance and Audit Committee 2018-07-25 - Agenda For The Chicago Board Of Education Finance And Audit Committee Meeting
# Document URL: https://www.documentcloud.org/documents/6512040-Finance-and-Audit-Committee-2018-07-25-Agenda.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2018-07-25 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512039-Board-of-Education-2018-07-25-Agenda-For-The.html
# Number of transfers extracted: 1308
# Keys: {'Number': 1308, 'Action': 1308, 'Name': 1308, 'Rationale': 1308, 'From Line 1': 1291, 'From Line 2': 1291, 'From Line 3': 1291, 'From Line 4': 1291, 'From Line 5': 1262, 'To Line 1': 1291, 'To Line 2': 1291, 'To Line 3': 1291, 'To Line 4': 1291, 'To Line 5': 1251, 'Amount': 1308, 'UNFORMATTED': 72}
#
# Document Name: Board of Education 2018-08-22 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512038-Board-of-Education-2018-08-22-Agenda-For-The.html
# Number of transfers extracted: 637
# Keys: {'Number': 637, 'Action': 637, 'Name': 637, 'Rationale': 637, 'From Line 1': 635, 'From Line 2': 635, 'From Line 3': 635, 'From Line 4': 635, 'From Line 5': 597, 'To Line 1': 635, 'To Line 2': 635, 'To Line 3': 635, 'To Line 4': 635, 'To Line 5': 634, 'Amount': 637, 'UNFORMATTED': 78}
#
# Document Name: Board of Education 2018-04-25 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512036-Board-of-Education-2018-04-25-Agenda-For-The.html
# Number of transfers extracted: 1433
# Keys: {'Number': 1433, 'Action': 1433, 'Name': 1433, 'Rationale': 1433, 'From Line 1': 1407, 'From Line 2': 1407, 'From Line 3': 1407, 'From Line 4': 1407, 'From Line 5': 1402, 'To Line 1': 1408, 'To Line 2': 1408, 'To Line 3': 1408, 'To Line 4': 1408, 'To Line 5': 1373, 'Amount': 1432, 'UNFORMATTED': 43}
#
# Document Name: Board of Education 2018-03-21 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512035-Board-of-Education-2018-03-21-Agenda-For-The.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2018-01-24 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512034-Board-of-Education-2018-01-24-Agenda-For-The.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Board of Education 2018-05-23 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512033-Board-of-Education-2018-05-23-Agenda-For-The.html
# Number of transfers extracted: 1088
# Keys: {'Number': 1088, 'Action': 1088, 'Name': 1088, 'Rationale': 1088, 'From Line 1': 1066, 'From Line 2': 1066, 'From Line 3': 1066, 'From Line 4': 1066, 'From Line 5': 1036, 'To Line 1': 1067, 'To Line 2': 1067, 'To Line 3': 1067, 'To Line 4': 1067, 'To Line 5': 1057, 'Amount': 1087, 'UNFORMATTED': 180}
#
# Document Name: Board of Education 2018-06-27 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512032-Board-of-Education-2018-06-27-Agenda-For-The.html
# Number of transfers extracted: 1199
# Keys: {'Number': 1199, 'Action': 1199, 'Name': 1199, 'Rationale': 1199, 'From Line 1': 1185, 'From Line 2': 1185, 'From Line 3': 1185, 'From Line 4': 1185, 'From Line 5': 1160, 'To Line 1': 1186, 'To Line 2': 1186, 'To Line 3': 1186, 'To Line 4': 1186, 'To Line 5': 1147, 'Amount': 1197, 'UNFORMATTED': 205}
#
# Document Name: Board of Education 2018-02-28 - Agenda For The Board Of Education
# Document URL: https://www.documentcloud.org/documents/6512031-Board-of-Education-2018-02-28-Agenda-For-The.html
# Number of transfers extracted: 0
# Keys: {}
#
# Document Name: Finance and Audit Committee 2018-01-24 - Agenda For The Chicago Board Of Education Finance And Audit Committee Meeting
# Document URL: https://www.documentcloud.org/documents/6512030-Finance-and-Audit-Committee-2018-01-24-Agenda.html
# Number of transfers extracted: 0
# Keys: {}
